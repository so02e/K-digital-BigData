# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 

driver = webdriver.Chrome('C:/Temp/chromedriver') # 내부적으로 웹드라이버 객체를 리턴 받는다. 이때 브라우저가 기동된다. 
print("WebDriver 객체 : ", type(driver))
# Out:
# WebDriver 객체 :  <class 'selenium.webdriver.chrome.webdriver.WebDriver'>

# %%
driver.get('http://www.google.com/ncr')

# %%
target=driver.find_element_by_css_selector("[name = 'q']")
print("찾아온 태그 객체 : ", type(target))
target.send_keys('파이썬')
target.send_keys(Keys.ENTER)
# Out:
# 찾아온 태그 객체 :  <class 'selenium.webdriver.remote.webelement.WebElement'>

# %%
import urllib.request
from bs4 import BeautifulSoup
#서버 접속
server = urllib.request.urlopen("https://www.istarbucks.co.kr/store/store_map.do")

response =server.read().decode()
bs = BeautifulSoup(response, "html.parser")
li = bs.find_all('li', class_="quickResultLstCon")
print(li)
# Out:
# []

# %%
driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(3)
driver.get("https://www.istarbucks.co.kr/store/store_map.do")
target=driver.find_element_by_class_name("quickResultLstCon")

print(type(target))
print(type(target.text))
print(target.text)
#driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f14b1bd8553c> in <module>
# ----> 1 driver = webdriver.Chrome('C:/Temp/chromedriver')
#       2 driver.implicitly_wait(3)
#       3 driver.get("https://www.istarbucks.co.kr/store/store_map.do")
#       4 target=driver.find_element_by_class_name("quickResultLstCon")
#       5
#
# NameError: name 'webdriver' is not defined

# %%
from selenium import webdriver

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(3)
print('[ webdriver 객체 정보 ]')
print(type(driver)) 
print(driver) 
driver.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')
print('-----------------------------')
byTagName = driver.find_element_by_tag_name('h1')
print(type(byTagName))
print(byTagName.tag_name, ":", byTagName.text)
print('-----------------------------')
byTagNames = driver.find_elements_by_tag_name('h2')
print(type(byTagNames))
for tagName in byTagNames :
   print(tagName.tag_name, ":", tagName.text)
#driver.quit()
# Out:
# [ webdriver 객체 정보 ]
# <class 'selenium.webdriver.chrome.webdriver.WebDriver'>
# <selenium.webdriver.chrome.webdriver.WebDriver (session="da8437b83130904db4e20e6d38a62154")>
# -----------------------------
# <class 'selenium.webdriver.remote.webelement.WebElement'>
# h1 : CSS 선택자 학습
# -----------------------------
# <class 'list'>
# h2 : 교육과정 소개
# h2 : 웹 클라이언트 기술
# h2 : 학습 순서(수집)

# %%
from selenium import webdriver

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(3) 

driver.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')

byClassName = driver.find_element_by_class_name('subtitle')
print(type(byClassName))
print(byClassName.tag_name, ":", byClassName.text)
print('-----------------------------')
byClassNames = driver.find_elements_by_class_name('subtitle')
print(type(byClassNames))
for className in byClassNames :
   print(className.tag_name, ":", className.text)
#driver.quit()
# Out:
# <class 'selenium.webdriver.remote.webelement.WebElement'>
# h2 : 웹 클라이언트 기술
# -----------------------------
# <class 'list'>
# h2 : 웹 클라이언트 기술
# h2 : 학습 순서(수집)

# %%
from selenium import webdriver

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(3) 

driver.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')

byId = driver.find_element_by_id('btype')
print(type(byId))
print(byId.tag_name, ":", byId.text)
print('-----------------------------')
byLinkText = driver.find_element_by_link_text('파이썬 학습 사이트')
print(type(byLinkText))
print(byLinkText.tag_name, ":", byLinkText.text)
print('-----------------------------')
byPLinkText = driver.find_elements_by_partial_link_text('사이트')
print(type(byPLinkText))
for linkText in byPLinkText :
   print(linkText.tag_name, ":", linkText.text)
#driver.quit()
# Out:
# <class 'selenium.webdriver.remote.webelement.WebElement'>
# li : HTML5
# -----------------------------
# <class 'selenium.webdriver.remote.webelement.WebElement'>
# a : 파이썬 학습 사이트
# -----------------------------
# <class 'list'>
# a : HTML, CSS, JavaScript 학습 사이트
# a : 파이썬 학습 사이트

# %%
from selenium import webdriver

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(3) 

driver.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')




print(type(byCss1))
print(byCss1.tag_name, ":", byCss1.text)
print('-----------------------------')
byCss2 = driver.find_element_by_css_selector('aside>h2')
print(type(byCss2))
print(byCss2.tag_name, ":", byCss2.text)
print('-----------------------------')
byCss3 = driver.find_element_by_css_selector('body > section > article > ul > li:nth-child(3)')
print(type(byCss3))
print(byCss3.tag_name, ":", byCss3.text)
print('-----------------------------')
byCss4 = driver.find_elements_by_css_selector('ul>li.atype')
print(type(byCss4))
for byCss in byCss4 :
   print(byCss.tag_name, ":", byCss.text)
#driver.quit()

# %%
from selenium import webdriver

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(3) 

driver.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')

byXpath1 = driver.find_element_by_xpath('//*[@id="f_subtitle"]')
print(type(byXpath1))
print(byXpath1.tag_name, ":", byXpath1.text)
print('-----------------------------')
byXpath2 = driver.find_element_by_xpath('/html/body/section/article/ul/li[3]')
print(type(byXpath2))
print(byXpath2.tag_name, ":", byXpath2.text)
print('-----------------------------')
byXpath3 = driver.find_elements_by_xpath('//ul/li[@class="atype"]')
print(type(byXpath3))
for byXpath in byXpath3 :
   print(byXpath.tag_name, ":", byXpath.text)
#driver.quit()

# %%
from selenium import webdriver

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(3) 

driver.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')

byXpath1 = driver.find_element_by_xpath('//div/img')
print(type(byXpath1))
print(byXpath1.tag_name, ":", byXpath1.get_attribute('src'))
print('-----------------------------')
byXpath2 = driver.find_elements_by_xpath('/html/body/header/nav/a')
print(type(byXpath2))
for byXpath in byXpath2 :
   print(byXpath.tag_name, ":", byXpath.get_attribute('href'))
#driver.quit()

# %%
from selenium import webdriver

driver = webdriver.Chrome('C:/Temp/chromedriver')

driver.get('http://www.python.org/')
driver.implicitly_wait(3)
driver.get_screenshot_as_file('/python_main.png')
print('캡쳐 저장 완료')
import time
time.sleep(5)
driver.quit()
# Out:
# 캡쳐 저장 완료

# %%
from selenium import webdriver

options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('window-size=1920x1080')

driver = webdriver.Chrome('C:/Temp/chromedriver', options=options)

driver.get('http://www.python.org/')
driver.implicitly_wait(3)
driver.get_screenshot_as_file('output/main_main_headless.png')
print('캡쳐 저장 완료')
import time
time.sleep(2)
driver.quit()

# %%
from selenium import webdriver

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(3) 

driver.get("https://www.istarbucks.co.kr/store/store_map.do")
import time
time.sleep(2)
loca = driver.find_element_by_class_name('loca_search')
loca.click()
time.sleep(2)
f_link = driver.find_element_by_css_selector("div.loca_step1_cont > ul > li:nth-child(1) > a")
f_link.click()
time.sleep(2)
s_link = driver.find_element_by_css_selector("#mCSB_2_container > ul > li:nth-child(1) > a")
s_link.click()
time.sleep(2)
shopList = driver.find_elements_by_css_selector("#mCSB_3_container > ul > li")

temp_list = []
time.sleep(3)
count = 0
total = len(shopList)
print(total)
for shop in shopList :    
    count += 1
    #print(count)
    shoplat = shop.get_attribute("data-lat")
    shoplong = shop.get_attribute("data-long")
    shopname = shop.find_element_by_tag_name("strong")
    shopinfo = shop.find_element_by_tag_name("p")
    splitinfo = shopinfo.text.split('\n')
    if(len(splitinfo) == 2):
        addr = splitinfo[0]
        phonenum = splitinfo[1]
    temp_list.append([shopname.text, shoplat, shoplong, addr, phonenum])
    if count != total and count % 3 == 0:
        driver.execute_script("var su = arguments[0]; var dom=document.querySelectorAll('#mCSB_3_container > ul > li')[su]; dom.scrollIntoView();", count)
with open('output/starbucks_shop.txt', "wt", encoding="utf-8") as f:
    for item in temp_list :
        f.write(str(item)+'\n')

#driver.quit()
# Out:
# 540

# %%
#소스1
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(3) 
driver.get('https://map.naver.com/') 
import time
time.sleep(2)

target=driver.find_element_by_css_selector(".input_search")

target.send_keys('서울시어린이도서관')
target.send_keys(Keys.ENTER)

time.sleep(2)
driver.switch_to.frame("searchIframe") 
while True :    
    names = driver.find_elements_by_css_selector("span._16f7Q")
    addrs = driver.find_elements_by_css_selector("span._3W_ec")
    if len(names) == 0 :
        print("추출되는 도서관이 더 이상 없슈")
        break
    for i in range(len(names)) :
        print(names[i].text,addrs[i].text, sep=", ", end="\n")
    print("------------------------------------------------")
    linkurl = '#app-root > div > div > div._2ky45 > a:nth-child(7)'
    try :
        linkNum = driver.find_element_by_css_selector(linkurl)
    except :
        print("더 이상 다음 페이지 없음")
        break
    linkNum.click()  
    time.sleep(5)
print("스크래핑 종료")
#driver.quit()
# Out:
# 국립어린이청소년도서관, 서울 강남구 역삼동
# 송파 어린이영어 작은도서관, 서울 송파구 신천동
# 서울특별시교육청 어린이도서관, 서울 종로구 사직동
# 동작어린이도서관, 서울 동작구 노량진동
# 노원어린이도서관, 서울 노원구 중계동
# 꿈꾸는어린이도서관, 서울 강서구 염창동
# 송파어린이도서관, 서울 송파구 잠실동
# 대방어린이도서관, 서울 동작구 대방동
# 글마루한옥어린이도서관, 서울 구로구 개봉동
# 마포어린이영어도서관, 서울 마포구 도화동
# ------------------------------------------------
# 꿈나무영유아도서관, 서울 관악구 신림동
# 아이리드, 서울 강남구 개포동
# 은평구립도서관 어린이열람실, 서울 은평구 불광동
# 꿈나무어린이도서관, 서울 송파구 가락동
# 이문어린이도서관, 서울 동대문구 이문동
# 맑은물어린이전문도서관, 서울 노원구 하계동
# 이마트키즈라이브러리 2호관, 서울 강서구 화곡동
# 영어도서관 리딩플라이, 서울 중랑구 묵동
# 꿈터마을 작은도서관, 서울 성북구 정릉동
# 무수골도서관, 서울 도봉구 도봉1동
# ------------------------------------------------
# 은평어린이영어도서관, 서울 은평구 역촌동
# 삼각산어린이도서관, 서울 강북구 미아동
# 까망돌어린이도서관, 서울 동작구 흑석동
# 좋은친구어린이도서관, 서울 강서구 공항동
# 어린이도서관 동네북, 서울 은평구 녹번동
# 신사어린이도서관, 서울 은평구 신사동
# 두껍아두껍아 어린이도서관, 서울 영등포구 대림동
# 가재울어린이도서관, 서울 서대문구 남가좌동
# 이문체육문화센터 어린이도서관, 서울 동대문구 이문동
# 어린이청소년국학도서관, 서울 종로구 명륜3가 1-21
# ------------------------------------------------
# 광진정보도서관, 서울 광진구 광장동
# 신길6동 공립작은도서관, 서울 영등포구 신길동
# 신길4동 새마을공립작은도서관, 서울 영등포구 신길동
# 여의동 공립작은도서관, 서울 영등포구 여의도동
# 양평2동 공립작은도서관, 서울 영등포구 양평동4가
# 신길5동꿈터마을도서관, 서울 영등포구 신길동
# 쁘띠몽드 마포중앙도서관점, 서울 마포구 성산동
# 토리영어도서관, 서울 중랑구 면목동
# 영등포본동 공립작은도서관, 서울 영등포구 영등포동
# 영등포2동새마을문고, 서울 영등포구 영등포동2가
# ------------------------------------------------
# 추출되는 도서관이 더 이상 없슈
# 스크래핑 종료

# %%
#소스2
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(3) 
driver.get('https://map.naver.com/') 
import time
time.sleep(2)

target=driver.find_element_by_css_selector(".input_search")

target.send_keys('서울시어린이도서관')
target.send_keys(Keys.ENTER)

time.sleep(2)
driver.switch_to.frame("searchIframe") # iframe 태그를 사용해서 구성된 페이지의 내용을 스크래핑 할 때 사용함. 
while True :
    count = 9
    while True :
        print("스크롤 : " +str(count))
        try :
            driver.execute_script("var su = arguments[0]; var dom=document.querySelectorAll('#_pcmap_list_scroll_container>ul>li')[su]; dom.scrollIntoView();", count)
            time.sleep(2)
        except :        
            break
        count += 10
    names = driver.find_elements_by_css_selector("span._16f7Q")
    addrs = driver.find_elements_by_css_selector("span._3W_ec")
    if len(names) == 0 :
        print("추출되는 도서관이 더 이상 없슈")
        break
    for i in range(len(names)) :
        print(names[i].text,addrs[i].text, sep=", ", end="\n")
    print("------------------------------------------------")
    linkurl = '#app-root > div > div > div._2ky45 > a:nth-child(7)'
    try :
        linkNum = driver.find_element_by_css_selector(linkurl)
    except :
        print("더 이상 다음 페이지 없음")
        break
    linkNum.click()  
    time.sleep(5)
print("스크래핑 종료")

#driver.quit()
# Out:
# 스크롤 : 9
# 스크롤 : 19
# 스크롤 : 29
# 스크롤 : 39
# 스크롤 : 49
# 스크롤 : 59
# 국립어린이청소년도서관, 서울 강남구 역삼동
# 송파 어린이영어 작은도서관, 서울 송파구 신천동
# 서울특별시교육청 어린이도서관, 서울 종로구 사직동
# 동작어린이도서관, 서울 동작구 노량진동
# 노원어린이도서관, 서울 노원구 중계동
# 꿈꾸는어린이도서관, 서울 강서구 염창동
# 송파어린이도서관, 서울 송파구 잠실동
# 대방어린이도서관, 서울 동작구 대방동
# 글마루한옥어린이도서관, 서울 구로구 개봉동
# 마포어린이영어도서관, 서울 마포구 도화동
# 도봉기적의도서관, 서울 도봉구 도봉동
# 중랑숲어린이도서관, 서울 중랑구 망우동
# 키즈니영어도서관, 서울 강남구 대치동
# 손기정어린이도서관, 서울 중구 만리동2가
# 신도림어린이영어작은도서관, 서울 구로구 신도림동
# 소나무언덕1호 작은도서관, 서울 송파구 풍납동
# 장안어린이도서관, 서울 동대문구 장안동
# 구로구립궁동어린이도서관, 서울 구로구 궁동
# 키즈스토리랜드위디딧, 서울 구로구 신도림동
# 구로 꿈나무어린이도서관, 서울 구로구 구로동
# 못골한옥어린이도서관, 서울 강남구 자곡동
# 용두어린이영어도서관, 서울 동대문구 용두동
# 도봉아이나라도서관, 서울 도봉구 창동
# 꿈나래어린이영어도서관, 서울 마포구 망원동
# 통인 어린이 작은도서관, 서울 종로구 통인동
# 구로구립개봉어린이도서관, 서울 구로구 개봉동
# 책읽는엄마 책읽는아이, 서울 성동구 금호동3가
# 위례 SR키즈 영어도서관, 서울 송파구 장지동
# 어깨동무 어린이 도서관, 서울 마포구 상암동
# 나들목가족도서관, 서울 동대문구 신설동
# 북트리 책읽어주는 도서관, 서울 중랑구 신내동
# 아리랑어린이도서관, 서울 성북구 돈암동
# 다섯콩작은도서관, 서울 은평구 녹번동
# 꿈 익는 책마을, 서울 동작구 상도동
# 해맞이장난감도서관, 서울 양천구 신월동
# 아차산아래 작은도서관 놀자, 서울 광진구 구의동
# 꿈나무마을책놀이방, 서울 은평구 응암동
# 용암어린이영어도서관, 서울 용산구 용산동2가
# 스토리빈 작은도서관, 서울 송파구 문정동
# 남산타운문화체육센터 어린이도서관, 서울 중구 약수동
# 길꽃어린이도서관, 서울 강서구 방화동
# 보들리안 영어독서, 서울 동작구 신대방동
# 몬스터도서관, 서울 광진구 구의동
# 인표어린이도서관, 서울 종로구 사직동
# 백련산 어린이도서관, 서울 은평구 응암동
# 하늘샘어린이도서관, 서울 서대문구 홍은2동
# 마포푸르메어린이도서관, 서울 마포구 상암동
# 반딧불어린이도서관, 서울 영등포구 문래동4가
# 루디아어린이영어도서관, 서울 강남구 세곡동
# 로알드 영어도서관, 서울 마포구 성산동
# ------------------------------------------------
# 스크롤 : 9
# 스크롤 : 19
# 스크롤 : 29
# 스크롤 : 39
# 스크롤 : 49
# 스크롤 : 59
# 꿈나무영유아도서관, 서울 관악구 신림동
# 아이리드, 서울 강남구 개포동
# 은평구립도서관 어린이열람실, 서울 은평구 불광동
# 꿈나무어린이도서관, 서울 송파구 가락동
# 이문어린이도서관, 서울 동대문구 이문동
# 맑은물어린이전문도서관, 서울 노원구 하계동
# 이마트키즈라이브러리 2호관, 서울 강서구 화곡동
# 영어도서관 리딩플라이, 서울 중랑구 묵동
# 꿈터마을 작은도서관, 서울 성북구 정릉동
# 무수골도서관, 서울 도봉구 도봉1동
# 숲속꿈나무어린이도서관, 서울 구로구 오류동
# 고척교회어린이도서관책마을, 서울 구로구 고척동
# 꿈나무어린이서점, 서울 노원구 중계2.3동
# 씽크엘작은도서관, 서울 강북구 미아동
# 강북교육문화원어린이도서관, 서울 강북구 번동
# 중화어린이도서관, 서울 중랑구 중화2동
# 신사2동 책사랑방, 서울 은평구 신사2동
# 느티나무어린이도서관, 서울 중구 신당동
# 다문화어린이작은책마루이음, 서울 성동구 도선동
# 어린이도서관책고리, 서울 성북구 보문동6가
# 장안꿈마루어린이 작은도서관, 서울 동대문구 장안동
# 물댄동산어린이도서관, 서울 성동구 성수동1가
# 어린이와작은도서관협회, 서울 마포구 서교동
# 도담도담어린이도서관, 서울 은평구 응암동
# 우리동네글방, 서울 마포구 합정동
# 성동구다문화어린이도서관, 서울 성동구 홍익동
# 작은 도서관 함께놀자, 서울 강북구 수유동
# 래미안상도3차 어린이문고, 서울 동작구 상도동
# 꿈나무어린이도서관, 서울 중랑구 신내동
# 환원어린이작은도서관, 서울 강서구 개화동
# 옐로우트리모자방, 서울 은평구 신사동
# 어린이보물찾기도서관, 서울 동대문구 회기동
# 어린이도서연구회, 서울 마포구 성산동
# 비름, 서울 도봉구 창동
# 석천문화관, 서울 종로구 명륜1가 4
# 녹색장난감도서관, 서울 중구 을지로1가
# 남가좌새롬어린이도서관, 서울 서대문구 남가좌2동
# 청파어린이영어도서관, 서울 용산구 청파동2가
# 새날도서관, 서울 성북구 종암동
# 꿈마루어린이도서관, 서울 동대문구 이문동
# 다문화도서관 모두, 서울 동대문구 회기동
# 어린이도서관 꿈틀, 서울 동대문구 전농동
# 빛어린이도서관, 서울 강남구 신사동
# 북마크 어린이도서관, 서울 영등포구 양평동4가
# 구립대조꿈나무 어린이도서관, 서울 은평구 대조동
# 서강어린이영어도서관, 서울 마포구 신수동
# 동대문구립휘경어린이도서관, 서울 동대문구 휘경동
# 성대골어린이도서관, 서울 동작구 상도동
# 은행나무어린이도서관, 서울 금천구 시흥동
# 문화촌어린이도서관, 서울 서대문구 홍제동
# ------------------------------------------------
# 스크롤 : 9
# 스크롤 : 19
# 스크롤 : 29
# 스크롤 : 39
# 스크롤 : 49
# 스크롤 : 59
# 은평어린이영어도서관, 서울 은평구 역촌동
# 삼각산어린이도서관, 서울 강북구 미아동
# 까망돌어린이도서관, 서울 동작구 흑석동
# 좋은친구어린이도서관, 서울 강서구 공항동
# 어린이도서관 동네북, 서울 은평구 녹번동
# 신사어린이도서관, 서울 은평구 신사동
# 두껍아두껍아 어린이도서관, 서울 영등포구 대림동
# 가재울어린이도서관, 서울 서대문구 남가좌동
# 이문체육문화센터 어린이도서관, 서울 동대문구 이문동
# 어린이청소년국학도서관, 서울 종로구 명륜3가 1-21
# 옹달샘어린이도서관, 서울 마포구 합정동
# 백합어린이도서관, 서울 용산구 후암동
# 꿈이있는어린이도서관, 서울 강서구 화곡동
# 쪼물왕국어린이도서관, 서울 영등포구 양평동4가
# 나무와 열매 어린이 도서관, 서울 종로구 무악동
# 삼청교회어린이도서관 꿈과쉼, 서울 종로구 팔판동
# 푸른나래어린이도서관, 서울 양천구 신월동
# 산돌어린이도서관, 서울 금천구 시흥1동
# 어린이도서관꿈터, 서울 성동구 사근동
# 서초어린이책마을, 서울 서초구 서초동
# 원천어린이도서관, 서울 서대문구 연희동
# 곰세마리 어린이 도서관, 서울 성북구 삼선동3가
# 강서성결어린이도서관, 서울 양천구 신월동
# 어린이도서관 느티나무, 서울 중구 신당동
# 새로운어린이도서관, 서울 중랑구 면목동
# 다모아어린이도서관, 서울 중랑구 면목동
# 어린이도서관꿈꾸는세상, 서울 서대문구 홍은2동
# 명지어린이영어도서관, 서울 서대문구 홍은2동
# 서문어린이도서관, 서울 은평구 응암동
# 주영광 어린이도서관, 서울 강북구 번동
# 어린이아뜰리에, 서울 용산구 이촌동
# 응봉동 어린이 작은도서관, 서울 성동구 응봉동
# 풍성한 어린이 영어작은 도서관, 서울 구로구 구로동
# 서울특별시립강남도서관 어린이실, 서울 강남구 삼성2동
# 꿈씨 어린이 작은도서관, 서울 금천구 독산4동
# 행당2동 어린이 작은도서관, 서울 성동구 행당동
# 금호4가동 주민센터어린이작은도서관, 서울 성동구 금호동4가
# 성수2가제1동 어린이작은도서관, 서울 성동구 성수동2가
# 금호2 3가어린이작은도서관, 서울 성동구 금호동2가
# 어린이 작은도서관 주영심 나무, 서울 광진구 중곡동
# 하늘어린이문고, 서울 강서구 화곡동
# 아름숲어린이문고, 서울 동대문구 전농동
# 사근동 어린이놀이터도서관, 서울 성동구 사근동
# 신도림 월드메르디앙 어린이 작은도서관, 서울 구로구 신도림동
# 도봉어린이문화정보센터, 서울 도봉구 창동
# 용답동 어린이작은도서관, 서울 성동구 용답동
# 소망의나무어린이작은도서관, 서울 금천구 시흥동
# 강서제일어린이문고, 서울 양천구 신월동
# 하예성 어린이문고, 서울 중랑구 면목본동
# 금호1가동어린이작은도서관, 서울 성동구 금호동1가
# ------------------------------------------------
# 스크롤 : 9
# 스크롤 : 19
# 스크롤 : 29
# 스크롤 : 39
# 광진정보도서관, 서울 광진구 광장동
# 신길6동 공립작은도서관, 서울 영등포구 신길동
# 신길4동 새마을공립작은도서관, 서울 영등포구 신길동
# 여의동 공립작은도서관, 서울 영등포구 여의도동
# 양평2동 공립작은도서관, 서울 영등포구 양평동4가
# 신길5동꿈터마을도서관, 서울 영등포구 신길동
# 쁘띠몽드 마포중앙도서관점, 서울 마포구 성산동
# 토리영어도서관, 서울 중랑구 면목동
# 영등포본동 공립작은도서관, 서울 영등포구 영등포동
# 영등포2동새마을문고, 서울 영등포구 영등포동2가
# 영등포동 공립작은도서관, 서울 영등포구 영등포동7가
# 위례장난감도서관, 서울 송파구 장지동
# 서울숲옆다루작은도서관, 서울 성동구 성수동1가
# 돌리네책빵, 서울 성북구 석관동
# 리더스하이영어도서관, 서울 광진구 구의동
# 국립중앙도서관책사랑어린이집, 서울 서초구 반포동
# 송파어린이도서관무인민원발급기, 서울 송파구 잠실동
# 꿈마루어린이도서관앞자전거대여소, 서울 동대문구 이문동
# 서울시립어린이도서관장애인용승강기, 서울 종로구 사직동
# 대조동꿈나무어린이도서관여성안심택배함, 서울 은평구 대조동
# 서부제일교회어린이도서관여성안심택배함, 서울 서대문구 홍은동
# 어린이도서관 개방화장실, 서울 노원구 상계동
# 꿈꾸는어린이도서관 개방화장실, 서울 강서구 염창동
# 송파어린이도서관 개방화장실, 서울 송파구 잠실동
# 송파어린이영어작은도서관 개방화장실, 서울 송파구 신천동
# 리드101 목동 1캠퍼스, 서울 양천구 목동
# 더 클래스 영어교실, 서울 광진구 광장동
# 점프업, 서울 마포구 성산동
# 서초구방배영어센터, 서울 서초구 방배동
# 시흥글로벌인재학당, 서울 금천구 시흥동
# TLC, 서울 노원구 중계동
# 리딩오션스, 서울 서초구 서초동
# 꿈꾸는도서관, 서울 서초구 양재동
# 대방어린이도서관 개방화장실, 서울 동작구 대방동
# 이노블스 대치직영점, 서울 강남구 대치동
# 해오름, 서울 영등포구 당산동5가
# 이노블스 목동직영점, 서울 양천구 목동
# 드림팩토리, 서울 강북구 미아동
# ------------------------------------------------
# 스크롤 : 9
# 추출되는 도서관이 더 이상 없슈
# 스크래핑 종료

# %%
from selenium import webdriver

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(3) 
driver.get("http://www.yes24.com/Product/goods/40936880")
import time
time.sleep(2)

stopFlag = False
while True :
  for n in range(4, 13) :
    linkurl = '#infoset_reviewContentList > div.review_sort.sortBot > div.review_sortLft > div > a:nth-child('+str(n)+')'
    linkNum = driver.find_element_by_css_selector(linkurl)
    linkNum.click()   
    time.sleep(2)
    readLinks = driver.find_elements_by_css_selector('#infoset_reviewContentList span.review_more')
    for readlink in readLinks :
      try :
        readlink.click()
      except :
        driver.execute_script("arguments[0].click", readlink)                  
      time.sleep(2)

    reviewList = driver.find_elements_by_css_selector('#infoset_reviewContentList div.reviewInfoBot.origin div.review_cont')
    for review in reviewList :    
      temp_list.append(review.text)
    
    if len(reviewList) < 5 :
      stopFlag = True
      break
      
  if stopFlag == True :
    break
  nextPage = '#infoset_reviewContentList > div.review_sort.sortBot > div.review_sortLft > div > a.bgYUI.next'
  linkNum = driver.find_element_by_css_selector(nextPage)
  linkNum.click()
  time.sleep(2)

print("스크래핑 끝!!")
wfile = open("output/yes24file.txt","w", encoding="utf-8") 
wfile.writelines(temp_list) 
wfile.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-50067fabfdf9> in <module>
#      24     reviewList = driver.find_elements_by_css_selector('#infoset_reviewContentList div.reviewInfoBot.origin div.review_cont')
#      25     for review in reviewList :
# ---> 26       temp_list.append(review.text)
#      27
#      28     if len(reviewList) < 5 :
#
# NameError: name 'temp_list' is not defined

# %%
from selenium import webdriver

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.implicitly_wait(3) 

driver.get("http://www.yes24.com/Product/goods/40936880")
import time
time.sleep(2)
readLinks = driver.find_elements_by_css_selector('#infoset_reviewContentList  div.btn_halfMore > a')

for readlink in readLinks :
    readlink.click()
    time.sleep(1)

# %%
reviewList = driver.find_elements_by_css_selector('#infoset_reviewContentList div.reviewInfoBot.origin div.review_cont')

temp_list = []
time.sleep(3)

for review in reviewList :    
    temp_list.append(review.text)
stopFlag = False
while True :
  for n in range(4, 13) :
    linkurl = '#infoset_reviewContentList > div.review_sort.sortBot > div.review_sortLft > div > a:nth-child('+str(n)+')'
    linkNum = driver.find_element_by_css_selector(linkurl)
    linkNum.click()   
    time.sleep(6)
    readLinks = driver.find_elements_by_css_selector('#infoset_reviewContentList span.review_more')
    ##infoset_reviewContentList > div:nth-child(4) > div.reviewInfoBot.crop > a > div > span
    for readlink in readLinks :
      readlink.click()
      time.sleep(3)

    reviewList = driver.find_elements_by_css_selector('#infoset_reviewContentList div.reviewInfoBot.origin div.review_cont')
    time.sleep(2)

    for review in reviewList :    
      temp_list.append(review.text)
    
    if len(reviewList) < 5 :
      stopFlag = True
      break
      
  if stopFlag == True :
    break
  nextPage = '#infoset_reviewContentList > div.review_sort.sortBot > div.review_sortLft > div > a.bgYUI.next'
  linkNum = driver.find_element_by_css_selector(nextPage)
  linkNum.click()
  time.sleep(2)

for item in temp_list :
    print(item)

wfile = open("output/yes24file.txt","w", encoding="utf-8") 
wfile.writelines(temp_list) 
wfile.close()

#driver.quit()
